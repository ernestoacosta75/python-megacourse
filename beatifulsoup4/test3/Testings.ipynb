# %%
import pandas
df = pandas.read_csv("F:\\foreignJMSFile.csv")
df
# Out:
#     TYPE;NAME;LOCAL;REMOTE;CHANNEL/QUEUE;OPTIONS;bsma0Cluster
# 0    F;replyQCFBsma0-UOR3-CLONI;replyQCFBsma0-UOR3-...
# 1    F;replyQCFBsma0CLONI_1;replyQCFBsma0CLONI_1;re...
# 2    F;replyQCFBsma0CLONI_2;replyQCFBsma0CLONI_2;re...
# 3    F;replyQCFReinoltro;replyQCFReinoltro;replyQCF...
# 4    F;replyQCFBsma0-UOR3-SPIMI;replyQCFBsma0-UOR3-...
# 5    F;replyQCFBsma0SPIMI_1;replyQCFBsma0SPIMI_1;re...
# 6    F;replyQCFBsma0SPIMI_2;replyQCFBsma0SPIMI_2;re...
# 7    D;UOS1INIZ.EQFA;UOS1INIZ.EQFA;QLOCAL.DATAGRAM....
# 8    D;UOS2FINE.EQFA;UOS2FINE.EQFA;QLOCAL.DATAGRAM....
# 9    D;UOS3DOUT.EQFA;UOS3DOUT.EQFA;QLOCAL.DATAGRAM....
# 10   D;UOS4APPO.EQFA;UOS4APPO.EQFA;QLOCAL.DATAGRAM....
# 11   D;UOREINOL.EQFA;UOREINOL.EQFA;QREMOTE.DATAGRAM...
# 12   D;UOS1INIZ.EF.DATAPOWER;UOS1INIZ.EF.DATAPOWER;...
# 13   D;UOS2FINE.EF.DATAPOWER;UOS2FINE.EF.DATAPOWER;...
# 14   D;UOS3DOUT.EF.DATAPOWER;UOS3DOUT.EF.DATAPOWER;...
# 15   D;UOS4APPO.EF.DATAPOWER;UOS4APPO.EF.DATAPOWER;...
# ...
